# %%
import pandas as pd

df = pd.read_csv('1.csv')

df = df.replace({',': '', ';': ','}, regex=True)

df.to_csv('modified_data.csv', index=False)

df
# Out:
#     Unnamed: 0                                            authors  \
# 0            0               S Rohini,Gowtham Ramesh,Anand Nair R
# 1            1           Sukul M.,Lakshmanan, S. Aswin,Gowtham R.
# 2            2                         Dharan Nidhin S,Gowtham R.
# 3            3           Johnson Shanoop,Gowtham R.,Nair Anand R.
# 4            4  Muppavarapu Vamsee, Gowtham Ramesh,Gyrard  Ame...
# 5            5  Gowtham R.,Sanjay S. P.,Shandilya Shishir Kuma...
# 6            6                        Gowtham Ramesh,Menen Anjali
# 7            7  Ravikumar Sourav,Vinod Dayanand,Gowtham Ramesh...
# 8            8                              Raghavi V.,Gowtham R.
# 9            9  Alampalli Ramu Nikhil,Bandarupalli Mohana Sai,...
# 10          10                           Menen Anjalee,Gowtham R.
# 11          11  Krishna N. Kaarthik,Prasanth M.,Gowtham R.,Kar...
# 12          12  Desul Sudarsana,Madurai Meenachi N.,Venkatesh ...
# ...
